# %%
import sys
import os
import numpy as np
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), ".."))) # tamto z pliku lab2 mi się wykrzaczało w jupyterze

# %%
from utility import (
    get_random_matrix_pair_any_size,
    get_random_matrix_any_size,
    get_random_vector_any_size
)

# %%
from benchmark_utility import (
    float_matrix_to_floatcounter_matrix,
    measure_FLOPS_and_runtime,
    show_FLOPS_plot,
    show_mult_comparison_plot,
    show_FLOPS_comparison_plot,
    show_runtime_plot,
    fit_curve_to_runtime_plot,
    show_runtime_comparison_plot,
    clear_file
)

# %%
from lab2 import (
    recursive_inverse,
    recursive_LU,
    recursive_Gauss,
    recursive_determinant
)

# %% [markdown]
# Pomiary

# %%
measure_FLOPS_and_runtime(function=recursive_inverse, n_args=1, ns=range(1, 500), filename='Data/recursive_inverse.txt') # 4,5h
# Out:
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:43: RuntimeWarning: overflow encountered in multiply
#   return a*b
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:71: RuntimeWarning: invalid value encountered in subtract
#   c11=p1+p4-p5+p7
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:72: RuntimeWarning: invalid value encountered in add
#   c12=p3+p5
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:74: RuntimeWarning: invalid value encountered in subtract
#   c22=p1-p2+p3+p6
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:73: RuntimeWarning: invalid value encountered in add
#   c21=p2+p4
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:74: RuntimeWarning: invalid value encountered in add
#   c22=p1-p2+p3+p6
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:71: RuntimeWarning: invalid value encountered in add
#   c11=p1+p4-p5+p7
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:74: RuntimeWarning: overflow encountered in add
#   c22=p1-p2+p3+p6
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:73: RuntimeWarning: overflow encountered in add
#   c21=p2+p4
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:72: RuntimeWarning: overflow encountered in add
#   c12=p3+p5
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:71: RuntimeWarning: overflow encountered in subtract
#   c11=p1+p4-p5+p7
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:74: RuntimeWarning: overflow encountered in subtract
#   c22=p1-p2+p3+p6
# c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:71: RuntimeWarning: overflow encountered in add
#   c11=p1+p4-p5+p7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 measure_FLOPS_and_runtime(function=recursive_inverse, n_args=1, ns=range(1, 500), filename='Data/recursive_inverse.txt')
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\benchmark_utility.py:34, in measure_FLOPS_and_runtime(function, n_args, ns, filename)
#      30 if n_args == 1:
#      32     start = time.time()
# ---> 34     function(A)
#      36     end = time.time()
#      38 elif n_args == 2:
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\lab2\lab2.py:55, in recursive_inverse(a)
#      51 b11 = a11inv + strassen(
#      52     strassen(strassen(strassen(a11inv, a12), s22inv), a21), a11inv
#      53 )
#      54 b12 = -strassen(strassen(a11inv, a12), s22inv)
# ---> 55 b21 = -strassen(strassen(s22inv, a21), a11inv)
#      56 b22 = s22inv
#      58 return unpad_matrix(
#      59     np.vstack((np.hstack((b11, b12)), np.hstack((b21, b22)))), original_shape
#      60 )
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:63, in strassen(a, b)
#      60 b21=b[mid:,:mid]
#      61 b22=b[mid:,mid:]
# ---> 63 p1 = strassen(a11+a22, b11+b22)
#      64 p2 = strassen(a21+a22, b11)
#      65 p3 = strassen(a11, b12-b22)
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:68, in strassen(a, b)
#      66 p4 = strassen(a22, b21-b11)
#      67 p5 = strassen(a11+a12, b22)
# ---> 68 p6 = strassen(a21-a11, b11+b12)
#      69 p7 = strassen(a12-a22, b21+b22)
#      71 c11=p1+p4-p5+p7
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:68, in strassen(a, b)
#      66 p4 = strassen(a22, b21-b11)
#      67 p5 = strassen(a11+a12, b22)
# ---> 68 p6 = strassen(a21-a11, b11+b12)
#      69 p7 = strassen(a12-a22, b21+b22)
#      71 c11=p1+p4-p5+p7
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:69, in strassen(a, b)
#      67 p5 = strassen(a11+a12, b22)
#      68 p6 = strassen(a21-a11, b11+b12)
# ---> 69 p7 = strassen(a12-a22, b21+b22)
#      71 c11=p1+p4-p5+p7
#      72 c12=p3+p5
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:66, in strassen(a, b)
#      64 p2 = strassen(a21+a22, b11)
#      65 p3 = strassen(a11, b12-b22)
# ---> 66 p4 = strassen(a22, b21-b11)
#      67 p5 = strassen(a11+a12, b22)
#      68 p6 = strassen(a21-a11, b11+b12)
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:69, in strassen(a, b)
#      67 p5 = strassen(a11+a12, b22)
#      68 p6 = strassen(a21-a11, b11+b12)
# ---> 69 p7 = strassen(a12-a22, b21+b22)
#      71 c11=p1+p4-p5+p7
#      72 c12=p3+p5
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\floatcounter.py:29, in FloatCounter.__sub__(self, value)
#      27 def __sub__(self, value):
#      28     FloatCounter.sub_counter += 1
# ---> 29     return FloatCounter(super().__sub__(value))
#
# KeyboardInterrupt:

# %%
for i in range(1, 251):
    
    A = get_random_matrix_any_size(i)
    
    measure_FLOPS_and_runtime('Data/recursive_inverse.txt', i, recursive_inverse, A)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 5
#       1 for i in range(1, 251):
#       3     A = get_random_matrix_any_size(i)
# ----> 5     measure_FLOPS_and_runtime('Data/recursive_inverse.txt', i, recursive_inverse, A)
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\benchmark_utility.py:35, in measure_FLOPS_and_runtime(filename, measurement_id, function, *args)
#      31 FloatCounter.reset_counters()
#      33 start = time.time()
# ---> 35 function(*args)
#      37 end = time.time()
#      39 results = FloatCounter.get_data()
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\lab2\lab2.py:54, in recursive_inverse(a)
#      49 s22inv = recursive_inverse(s22)
#      51 b11 = a11inv + strassen(
#      52     strassen(strassen(strassen(a11inv, a12), s22inv), a21), a11inv
#      53 )
# ---> 54 b12 = -strassen(strassen(a11inv, a12), s22inv)
#      55 b21 = -strassen(strassen(s22inv, a21), a11inv)
#      56 b22 = s22inv
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:69, in strassen(a, b)
#      67 p5 = strassen(a11+a12, b22)
#      68 p6 = strassen(a21-a11, b11+b12)
# ---> 69 p7 = strassen(a12-a22, b21+b22)
#      71 c11=p1+p4-p5+p7
#      72 c12=p3+p5
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:68, in strassen(a, b)
#      66 p4 = strassen(a22, b21-b11)
#      67 p5 = strassen(a11+a12, b22)
# ---> 68 p6 = strassen(a21-a11, b11+b12)
#      69 p7 = strassen(a12-a22, b21+b22)
#      71 c11=p1+p4-p5+p7
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:73, in strassen(a, b)
#      71 c11=p1+p4-p5+p7
#      72 c12=p3+p5
# ---> 73 c21=p2+p4
#      74 c22=p1-p2+p3+p6
#      76 return unpad_matrix(np.vstack((np.hstack((c11,c12)),np.hstack((c21,c22)))), original_shape)
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\floatcounter.py:21, in FloatCounter.__add__(self, value)
#      19 def __add__(self, value):
#      20     FloatCounter.add_counter += 1
# ---> 21     return FloatCounter(super().__add__(value))
#
# KeyboardInterrupt:

# %%
measure_FLOPS_and_runtime(function=recursive_LU, n_args=1, ns=range(1, 251), filename='Data/recursive_lu.txt') # 4h

# %%
for i in range(1, 251):
    
    A = get_random_matrix_any_size(i)
    
    measure_FLOPS_and_runtime('Data/recursive_lu.txt', i, recursive_LU, A)

# %%
for i in range(1, 251):

    A = get_random_matrix_any_size(i)
    V = get_random_vector_any_size(i)

    measure_FLOPS_and_runtime('Data/recursive_gauss.txt', i, recursive_Gauss, A, V)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 6
#       3 A = get_random_matrix_any_size(i)
#       4 V = get_random_vector_any_size(i)
# ----> 6 measure_FLOPS_and_runtime('Data/recursive_gauss.txt', i, recursive_Gauss, A, V)
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\benchmark_utility.py:35, in measure_FLOPS_and_runtime(filename, measurement_id, function, *args)
#      31 FloatCounter.reset_counters()
#      33 start = time.time()
# ---> 35 function(*args)
#      37 end = time.time()
#      39 results = FloatCounter.get_data()
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\lab2\lab2.py:115, in recursive_Gauss(a, b)
#     112 b1 = b[:mid]
#     113 b2 = b[mid:]
# --> 115 l11, u11 = recursive_LU(a11)
#     116 l11inv = recursive_inverse(l11)
#     117 u11inv = recursive_inverse(u11)
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\lab2\lab2.py:81, in recursive_LU(a)
#      79 u11inv = recursive_inverse(u11)
#      80 l21 = strassen(a21, u11inv)
# ---> 81 l11inv = recursive_inverse(l11)
#      82 u12 = strassen(l11inv, a12)
#      83 s = a22 - strassen(strassen(strassen(a21, u11inv), l11inv), a12)
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\lab2\lab2.py:49, in recursive_inverse(a)
#      47 a11inv = recursive_inverse(a11)
#      48 s22 = a22 - strassen(strassen(a21, a11inv), a12)
# ---> 49 s22inv = recursive_inverse(s22)
#      51 b11 = a11inv + strassen(
#      52     strassen(strassen(strassen(a11inv, a12), s22inv), a21), a11inv
#      53 )
#      54 b12 = -strassen(strassen(a11inv, a12), s22inv)
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\lab2\lab2.py:54, in recursive_inverse(a)
#      49 s22inv = recursive_inverse(s22)
#      51 b11 = a11inv + strassen(
#      52     strassen(strassen(strassen(a11inv, a12), s22inv), a21), a11inv
#      53 )
# ---> 54 b12 = -strassen(strassen(a11inv, a12), s22inv)
#      55 b21 = -strassen(strassen(s22inv, a21), a11inv)
#      56 b22 = s22inv
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:65, in strassen(a, b)
#      63 p1 = strassen(a11+a22, b11+b22)
#      64 p2 = strassen(a21+a22, b11)
# ---> 65 p3 = strassen(a11, b12-b22)
#      66 p4 = strassen(a22, b21-b11)
#      67 p5 = strassen(a11+a12, b22)
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:67, in strassen(a, b)
#      65 p3 = strassen(a11, b12-b22)
#      66 p4 = strassen(a22, b21-b11)
# ---> 67 p5 = strassen(a11+a12, b22)
#      68 p6 = strassen(a21-a11, b11+b12)
#      69 p7 = strassen(a12-a22, b21+b22)
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:65, in strassen(a, b)
#      63 p1 = strassen(a11+a22, b11+b22)
#      64 p2 = strassen(a21+a22, b11)
# ---> 65 p3 = strassen(a11, b12-b22)
#      66 p4 = strassen(a22, b21-b11)
#      67 p5 = strassen(a11+a12, b22)
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\Lab1\matrix_mult.py:68, in strassen(a, b)
#      66 p4 = strassen(a22, b21-b11)
#      67 p5 = strassen(a11+a12, b22)
# ---> 68 p6 = strassen(a21-a11, b11+b12)
#      69 p7 = strassen(a12-a22, b21+b22)
#      71 c11=p1+p4-p5+p7
#
# File c:\Users\48667\Documents\AGH UST\Semestr5\Algorytmy-Macierzowe\floatcounter.py:21, in FloatCounter.__add__(self, value)
#      19 def __add__(self, value):
#      20     FloatCounter.add_counter += 1
# ---> 21     return FloatCounter(super().__add__(value))
#
# KeyboardInterrupt:

# %%
measure_FLOPS_and_runtime(function=recursive_determinant, n_args=1, ns=range(1, 251), filename='Data/recursive_determinant.txt') # 4h

# %%
for i in range(1, 251):
    
    A = get_random_matrix_any_size(i)
    
    measure_FLOPS_and_runtime('Data/recursive_determinant.txt', i, recursive_determinant, A)

# %% [markdown]
# Wykresy wykresiki

# %%
show_FLOPS_plot('Data/recursive_inverse.txt', 'recursive inverse')

# %%
show_FLOPS_plot('Data/recursive_lu.txt', 'recursive lu')

# %%
show_FLOPS_plot('Data/recursive_gauss.txt', 'recursive gauss')

# %%
show_FLOPS_plot('Data/recursive_determinant.txt', 'recursive determinant')

# %%
show_mult_comparison_plot(
    ['Data/recursive_inverse.txt', 'Data/recursive_lu.txt', 'Data/recursive_determinant.txt', 'Data/recursive_gauss.txt'],
    ['revcursive inverse', 'recursive lu', 'recursive determinant', 'recursive gauss']
    )

# %%
show_FLOPS_comparison_plot(
    ['Data/recursive_inverse.txt', 'Data/recursive_lu.txt', 'Data/recursive_determinant.txt', 'Data/recursive_gauss.txt'],
    ['revcursive inverse', 'recursive lu', 'recursive determinant', 'recursive gauss']
    )

# %%
show_runtime_plot('Data/recursive_inverse.txt', 'recursive inverse')

# %%
fit_curve_to_runtime_plot('Data/recursive_inverse.txt', 'recursive inverse', lambda x : x**2.81, "n**2.81")

# %%
show_runtime_plot('Data/recursive_lu.txt', 'recursive lu')

# %%
fit_curve_to_runtime_plot('Data/recursive_lu.txt', 'recursive lu', lambda x : x**2.81, "n**2.81")

# %%
show_runtime_plot('Data/recursive_determinant.txt', 'recursive determinant')

# %%
fit_curve_to_runtime_plot('Data/recursive_determinant.txt', 'recursive determinant', lambda x : x**2.81, "n**2.81")

# %%
show_runtime_plot('Data/recursive_gauss.txt', 'recursive gauss')

# %%
fit_curve_to_runtime_plot('Data/recursive_gauss.txt', 'recursive gauss', lambda x : x**2.81, "n**2.81")

# %%
show_runtime_comparison_plot(
    ['Data/recursive_inverse.txt', 'Data/recursive_lu.txt', 'Data/recursive_determinant.txt', 'Data/recursive_gauss.txt'],
    ['revcursive inverse', 'recursive lu', 'recursive determinant', 'recursive gauss']
)

# %% [markdown]
# Porównanie wyników z octave

# %%
A = np.array([[1.12, 6.31, 3.52, 5.31, 3.23],
     [2.43, 5.23, 7.43, 6.54, 2.22],
     [0.76, 4.98, 7.86, 4.00, 7.43],
     [9.99, 4.33, 5.44, 3.45, 2.45],
     [6.43, 5.44, 3.23, 1.23, 2.67]])

A_inv = recursive_inverse(A)

print(A_inv)
# Out:
# [[ 0.02828355 -0.08468873 -0.01700191  0.15894487 -0.0623362 ]
#  [ 0.00245146  0.10607761 -0.07566418 -0.23734449  0.33717916]
#  [-0.30839429  0.2735043   0.03712922 -0.151527    0.18138766]
#  [ 0.27982703 -0.11229532 -0.03122072  0.24472092 -0.3828247 ]
#  [ 0.17105885 -0.29131435  0.16457285  0.17137227 -0.20540847]]

# %%
A = np.array([[1.12, 6.31, 3.52, 5.31, 3.23],
     [2.43, 5.23, 7.43, 6.54, 2.22],
     [0.76, 4.98, 7.86, 4.00, 7.43],
     [9.99, 4.33, 5.44, 3.45, 2.45],
     [6.43, 5.44, 3.23, 1.23, 2.67]])

L, U = recursive_LU(A)

print("L = ")
print(L)
print("U = ")
print(U)
# Out:
# L =
# [[ 1.          0.          0.          0.          0.        ]
#  [ 2.16964286  1.          0.          0.          0.        ]
#  [ 0.67857143 -0.08252688  1.          0.          0.        ]
#  [ 8.91964286  6.14068618 -4.52578534  1.          0.        ]
#  [ 5.74107143  3.63883407 -2.97466451  0.83429996  1.        ]]
# U =
# [[ 1.12000000e+00  6.31000000e+00  3.52000000e+00  5.31000000e+00
#    3.23000000e+00]
#  [ 0.00000000e+00 -8.46044643e+00 -2.07142857e-01 -4.98080357e+00
#   -4.78794643e+00]
#  [ 0.00000000e+00  0.00000000e+00  5.45433372e+00 -1.42644871e-02
#    4.84307998e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 -1.33923099e+01
#    2.49595704e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -4.86834850e+00]]

# %%
A = np.array([[1.12, 6.31, 3.52, 5.31, 3.23],
     [2.43, 5.23, 7.43, 6.54, 2.22],
     [0.76, 4.98, 7.86, 4.00, 7.43],
     [9.99, 4.33, 5.44, 3.45, 2.45],
     [6.43, 5.44, 3.23, 1.23, 2.67]])

b = np.array([1.23, 2.12, 7.54, 8.55, 3.45])

lhs, rhs = recursive_Gauss(A, b)

print("lhs = ")
for x in lhs:
     print(x)
print("rhs = ")
print(rhs)
# Out:
# lhs =
# [1.12 6.31 3.52 5.31 3.23]
# [ 0.         -8.46044643 -0.20714286 -4.98080357 -4.78794643]
# [ 0.          0.          5.45433372 -0.01426449  4.84307998]
# [  0.           0.           0.         -13.39230994  24.95957041]
# [ 0.         0.         0.         0.        -4.8683485]
# rhs =
# [ 1.23       -0.54866071  6.66007788 31.0900754  -7.74198382]

# %%
A = np.array([[1.12, 6.31, 3.52, 5.31, 3.23],
     [2.43, 5.23, 7.43, 6.54, 2.22],
     [0.76, 4.98, 7.86, 4.00, 7.43],
     [9.99, 4.33, 5.44, 3.45, 2.45],
     [6.43, 5.44, 3.23, 1.23, 2.67]])

det_A = recursive_determinant(A)

print(det_A)
# Out:
# -3369.6916398120434
